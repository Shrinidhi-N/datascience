# %% [markdown]
# ![dimg.png](attachment:dimg.png)

# %% [raw]
#                                                  Prediction Model and EDA

# %% [raw]
#                                                                                                        By - Shrinidhi N

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"E:\Shrinidhi\Internship\ML with Python Internship\Project\breast-cancer-wisconsin.csv")

# %%
df.shape
# Out:
# (699, 11)

# %%
df.columns
# Out:
# Index(['id number', 'Clump Thickness', 'Uniformity of Cell Size',
#        'Uniformity of Cell Shape', 'Marginal Adhesion',
#        'Single Epithelial Cell Size', ' Bare Nuclei', ' Bland Chromatin',
#        'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
df.head()
# Out:
#    id number  Clump Thickness  Uniformity of Cell Size  \
# 0    1000025                5                        1
# 1    1002945                5                        4
# 2    1015425                3                        1
# 3    1016277                6                        8
# 4    1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#     Bare Nuclei   Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0           1.0                 3                1        1      2
# ...

# %%
df.describe()
# Out:
#           id number  Clump Thickness  Uniformity of Cell Size  \
# count  6.990000e+02       699.000000               699.000000
# mean   1.071704e+06         4.417740                 3.134478
# std    6.170957e+05         2.815741                 3.051459
# min    6.163400e+04         1.000000                 1.000000
# 25%    8.706885e+05         2.000000                 1.000000
# 50%    1.171710e+06         4.000000                 1.000000
# 75%    1.238298e+06         6.000000                 5.000000
# max    1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                699.000000         699.000000
# mean                   3.207439           2.806867
# std                    2.971913           2.855379
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# 50%                    1.000000           1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id number                    699 non-null    int64
#  1   Clump Thickness              699 non-null    int64
#  2   Uniformity of Cell Size      699 non-null    int64
#  3   Uniformity of Cell Shape     699 non-null    int64
#  4   Marginal Adhesion            699 non-null    int64
#  5   Single Epithelial Cell Size  699 non-null    int64
#  6    Bare Nuclei                 683 non-null    float64
#  7    Bland Chromatin             699 non-null    int64
#  8   Normal Nucleoli              699 non-null    int64
#  9   Mitoses                      699 non-null    int64
#  10  Class                        699 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 60.2 KB

# %%
df=df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# id number                       0
# Clump Thickness                 0
# Uniformity of Cell Size         0
# Uniformity of Cell Shape        0
# Marginal Adhesion               0
# Single Epithelial Cell Size     0
#  Bare Nuclei                   16
#  Bland Chromatin                0
# Normal Nucleoli                 0
# Mitoses                         0
# Class                           0
# dtype: int64

# %%
df.replace(r' ', np.NaN)
# Out:
#      id number  Clump Thickness  Uniformity of Cell Size  \
# 0      1000025                5                        1
# 1      1002945                5                        4
# 2      1015425                3                        1
# 3      1016277                6                        8
# 4      1017023                4                        1
# ..         ...              ...                      ...
# 694     776715                3                        1
# 695     841769                2                        1
# 696     888820                5                       10
# 697     897471                4                        8
# 698     897471                4                        8
#
#      Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                           1                  1                            2
# 1                           4                  5                            7
# ...

# %%
df.head(25)
# Out:
#     id number  Clump Thickness  Uniformity of Cell Size  \
# 0     1000025                5                        1
# 1     1002945                5                        4
# 2     1015425                3                        1
# 3     1016277                6                        8
# 4     1017023                4                        1
# 5     1017122                8                       10
# 6     1018099                1                        1
# 7     1018561                2                        1
# 8     1033078                2                        1
# 9     1033078                4                        2
# 10    1035283                1                        1
# 11    1036172                2                        1
# 12    1041801                5                        3
# 13    1043999                1                        1
# 14    1044572                8                        7
# 15    1047630                7                        4
# ...

# %%
df=df.fillna(df.mean())

# %%
df.head(25)
# Out:
#     id number  Clump Thickness  Uniformity of Cell Size  \
# 0     1000025                5                        1
# 1     1002945                5                        4
# 2     1015425                3                        1
# 3     1016277                6                        8
# 4     1017023                4                        1
# 5     1017122                8                       10
# 6     1018099                1                        1
# 7     1018561                2                        1
# 8     1033078                2                        1
# 9     1033078                4                        2
# 10    1035283                1                        1
# 11    1036172                2                        1
# 12    1041801                5                        3
# 13    1043999                1                        1
# 14    1044572                8                        7
# 15    1047630                7                        4
# ...

# %%
df=df.round(2)

# %%
df.head(25)
# Out:
#     id number  Clump Thickness  Uniformity of Cell Size  \
# 0     1000025                5                        1
# 1     1002945                5                        4
# 2     1015425                3                        1
# 3     1016277                6                        8
# 4     1017023                4                        1
# 5     1017122                8                       10
# 6     1018099                1                        1
# 7     1018561                2                        1
# 8     1033078                2                        1
# 9     1033078                4                        2
# 10    1035283                1                        1
# 11    1036172                2                        1
# 12    1041801                5                        3
# 13    1043999                1                        1
# 14    1044572                8                        7
# 15    1047630                7                        4
# ...

# %%
df=df.drop("Uniformity of Cell Shape",axis=1)

# %%
df.head()
# Out:
#    id number  Clump Thickness  Uniformity of Cell Size  Marginal Adhesion  \
# 0    1000025                5                        1                  1
# 1    1002945                5                        4                  5
# 2    1015425                3                        1                  1
# 3    1016277                6                        8                  1
# 4    1017023                4                        1                  3
#
#    Single Epithelial Cell Size   Bare Nuclei   Bland Chromatin  \
# 0                            2           1.0                 3
# 1                            7          10.0                 3
# 2                            2           2.0                 3
# 3                            3           4.0                 3
# 4                            2           1.0                 3
#
#    Normal Nucleoli  Mitoses  Class
# 0                1        1      2
# 1                2        1      2
# ...

# %%
x=df.drop("Class",axis=1)
y=df["Class"]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (552, 9)
# (139, 9)
# (552,)
# (139,)

# %%
from sklearn.linear_model import LinearRegression
algo=LinearRegression()

# %%
algo.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
algo.intercept_
# Out:
# 1.481867557284898

# %%
algo.coef_
# Out:
# array([-4.34202821e-09,  7.46435687e-02,  6.47982355e-02,  2.06173874e-02,
#         1.54565247e-02,  8.41456432e-02,  4.71673804e-02,  3.93048676e-02,
#         5.84728686e-04])

# %%
ypred=algo.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(ytest,ypred))
# Out:
# 0.2181927361686137

# %%
from sklearn.metrics import r2_score
print(r2_score(ytest,ypred))
# Out:
# 0.8701599155999923

# %%
import joblib
joblib.dump(algo,r"E:\Shrinidhi\Internship\ML with Python Internship\Project\linear-model.pkl")
# Out:
# ['E:\\Shrinidhi\\Internship\\ML with Python Internship\\Project\\linear-model.pkl']

# %% [raw]
# EDA

# %%
df.columns
# Out:
# Index(['id number', 'Clump Thickness', 'Uniformity of Cell Size',
#        'Marginal Adhesion', 'Single Epithelial Cell Size', ' Bare Nuclei',
#        ' Bland Chromatin', 'Normal Nucleoli', 'Mitoses', 'Class'],
#       dtype='object')

# %%
sns.countplot(x="Class",data=df)
plt.show()

# %% [raw]
# Analysis: Here more than 450 people are having class 2 type of Cancer

# %%
sns.countplot(x="Mitoses", hue="Class",data=df)
plt.show()

# %% [raw]
# Analysis: Here most of the Class 2 patients have less mitoses whereas class 4 patients have large mitosis

# %%
sns.countplot(x="Single Epithelial Cell Size", hue="Class",data=df)
plt.show()

# %% [raw]
# Analysis: Here we can understand that more than 350 patients of class 2 category has epithelial cell size 2

# %%
sns.scatterplot(x="Clump Thickness",y="Mitoses",hue="Class",data=df)
plt.show()

# %% [raw]
# Analysis: Here we can know that class 2 patients have less mitoses and Clump thickness is also less , Whereas class 4 patients have larger Clump thickness has high mitoses.

# %%
sns.scatterplot(x="Uniformity of Cell Size",y="Marginal Adhesion",hue="Class",data=df)
plt.show()

# %% [raw]
# Analysis: Class 4 has higher Marginal Adhesion and uniformity of cell size.
